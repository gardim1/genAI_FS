# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/Qwen/QwQ-32B',
#  '/google/gemma-3-27b-it',
#  '/deepseek-ai/DeepSeek-R1',
#  '/SparkAudio/Spark-TTS-0.5B',
#  '/RekaAI/reka-flash-3',
#  '/models',
#  '/spaces/Wan-AI/Wan2.1',
#  '/spaces/Qwen/QwQ-32B-Demo',
#  '/spaces/ASLP-lab/DiffRhythm',
#  '/spaces/nanotron/ultrascale-playbook',
#  '/spaces/black-forest-labs/FLUX.1-dev',
#  '/spaces',
#  '/datasets/FreedomIntelligence/medical-o1-reasoning-SFT',
#  '/datasets/facebook/natural_reasoning',
#  '/datasets/Congliu/Chinese-DeepSeek-R1-Distill-data-110k',
#  '/datasets/gaia-benchmark/GAIA',
#  '/datasets/KodCode/KodCode-V1',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community discussion page',
#    'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'forum page', 'url': 'https://discuss.huggingface.co'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/QwQ-32B
# Updated
# 2 days ago
# •
# 256k
# •
# 2.11k
# google/gemma-3-27b-it
# Updated
# 1 day ago
# •
# 38.5k
# •
# 459
# deepseek-ai/DeepSeek-R1
# Updated
# 18 days ago
# •
# 2.75M
# •
# 11.3k
# SparkAudio/Spark-TTS-0.5B
# Updated
# 7 days ago
# •
# 7.82k
# •
# 380
# RekaAI/reka-flash-3
# Updated
# about 5 hours ago
# •
# 1.3k
# •
# 221
# Browse 1M+ models
# Spaces
# Running
# 1.14k
# 1.14k
# Wan2.1
# 💻
# Wan: Open and Advanced Large-Scale Video Generative Models
# Running
# 371
# 371
# QwQ 32B Demo
# 🌖
# Generate text responses to user prompts
# Running
# on
# Zero
# 417
# 417
# Di♪♪Rhythm
# 🎶
# Blazingly Fast and Embarrassingly Simple Song Generation
# Running
# 2.24k
# 2.24k
# The Ultra-Scale Playbook
# 🌌
# The ultimate guide to training LLM on large GPU Clusters
# Running
# on
# Zero
# 7.79k
# 7.79k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Browse 400k+ applications
# Datasets
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# 20 days ago
# •
# 27.9k
# •
# 445
# facebook/natural_reasoning
# Updated
# 21 days ago
# •
# 10.7k
# •
# 398
# Congliu/Chinese-DeepSeek-R1-Distill-data-110k
# Updated
# 21 days ago
# •
# 7.74k
# •
# 522
# gaia-benchmark/GAIA
# Updated
# 28 days ago
# •
# 8.94k
# •
# 258
# KodCode/KodCode-V1
# Updated
# 4 days ago
# •
# 3.02k
# •
# 63
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 395 models
# •
# 2.79k followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.04k followers
# Amazon
# company
# •
# 11 models
# •
# 2.85k followers
# Google
# company
# •
# 968 models
# •
# 9.2k followers
# Intel
# company
# •
# 219 models
# •
# 2.33k followers
# Microsoft
# company
# •
# 363 models
# •
# 10.2k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 135 followers
# Writer
# Enterprise
# company
# •
# 20 models
# •
# 249 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 141,156
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 27,999
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,161
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,426
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,473
# Fast tokenizers optimized for research & production
# TRL
# 12,475
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,195
# State-of-the-art ML running directly in your browser
# smolagents
# 14,664
# Smol library to build great agents in Python
# PEFT
# 17,746
# Parameter-efficient finetuning for large language models
# Datasets
# 19,779
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,879
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,472
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 25,282
# AI & ML interests
# The AI community building the future.
# Recent Activity
# Wauplin
# new
# activity
# about 4 hours ago
# huggingface/HuggingDiscussions:
# [FEEDBACK] Follow
# a-r-r-o-w
# new
# activity
# about 24 hours ago
# huggingface/documentation-images:
# Upload folder using huggingface_hub
# abidlabs
# updated
# a dataset
# 1 day ago
# huggingface/documentation-images
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 36
# Team members
# 209
# +175
# +162
# +141
# +131
# +111
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 285k
# •
# •
# 37
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 12.2M
# •
# •
# 642
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 1.64M
# •
# •
# 176
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 6.69M
# •
# •
# 707
# spaces
# 24
# Sort:
# 		Recently updated
# pinned
# Running
# 72
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 112
# Inference Playground
# 🔋
# Engage in chat conversations
# huggingface
# 2 days ago
# Running
# 319
# AI Deadlines
# ⚡
# Schedule tasks efficiently using AI-generated deadlines
# huggingface
# 5 days ago
# Running
# 533
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Running
# 218
# paper-central
# ⚡
# Explore and manage research papers
# huggingface
# Dec 13, 2024
# Running
# on
# TPU v5e
# 9
# Keras Chatbot Battle
# 💬
# Interact with multiple chatbots simultaneously
# huggingface
# Dec 5, 2024
# Expand 24
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 273
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 7.19k
# •
# •
# 58
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 42
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 46.3k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 334
# •
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 33.7k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 5.62k
# •
# 19
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 41
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 35.8k
# •
# 79
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 24 hours ago
# •
# 50
# •
# 4.94M
# •
# 53
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.58k
# •
# 5.05k
# •
# 16
# huggingface/policy-docs
# Updated
# 8 days ago
# •
# 2.14k
# •
# 9
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# 10 days ago
# •
# 17
# •
# 30
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# 13 days ago
# •
# 21
# •
# 29
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# 13 days ago
# •
# 24
# •
# 28
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# 16 days ago
# •
# 32
# •
# 40
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# 17 days ago
# •
# 32
# •
# 49
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 17 days ago
# •
# 68
# •
# 664
# •
# 5
# huggingface/gemini-results-2025-02-21
# Viewer
# •
# Updated
# 19 days ago
# •
# 29
# •
# 140
# •
# 1
# Expand 42
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 291 models
# •
# 18.4k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 285 followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.04k followers
# Writer
# Enterprise
# company
# •
# 20 models
# •
# 249 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 184 followers
# Fidelity Investments
# Enterprise
# company
# •
# 127 followers
# Mistral AI_
# Enterprise
# company
# •
# 23 models
# •
# 6.11k followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.25k followers
# Chegg Inc
# Enterprise
# company
# •
# 84 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 61 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 55 followers
# Stability AI
# Enterprise
# company
# •
# 103 models
# •
# 18.4k followers
# Novo Nordisk
# Enterprise
# company
# •
# 63 followers
# Kakao Corp.
# Enterprise
# company
# •
# 3 models
# •
# 94 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 31.6k followers
# Snowflake
# Enterprise
# company
# •
# 14 models
# •
# 454 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 190 followers
# Arm
# Enterprise
# company
# •
# 154 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 102 followers
# Jusbrasil
# Enterprise
# company
# •
# 85 followers
# Procter & Gamble
# Enterprise
# company
# •
# 74 followers
# IBM Granite
# Enterprise
# company
# •
# 94 models
# •
# 1.25k followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 63 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 135 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 565 followers
# StepFun
# Enterprise
# company
# •
# 7 models
# •
# 775 followers
# Widn AI
# Enterprise
# company
# •
# 40 followers
# Gretel.ai
# Enterprise
# company
# •
# 9 models
# •
# 107 followers
# Shopify
# Enterprise
# company
# •
# 421 followers
# AMD
# Enterprise
# company
# •
# 99 models
# •
# 1.4k followers
# Together
# Enterprise
# company
# •
# 32 models
# •
# 539 followers
# Xsolla
# Enterprise
# company
# •
# 115 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 131 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 137 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 407 followers
# Aledade Inc
# Enterprise
# company
# •
# 63 followers
# creditkarma
# Enterprise
# company
# •
# 51 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 62 followers
# Arcee AI
# Enterprise
# company
# •
# 155 models
# •
# 458 followers
# Liberty Mutual
# Enterprise
# company
# •
# 44 followers
# BCG X
# Enterprise
# company
# •
# 36 followers
# Adyen
# Enterprise
# company
# •
# 52 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Welcome Gemma 3: Google's all new multimodal, multilingual, long context open LLM
# By
# ariG23498
# March 12, 2025
# •
# 196
# Community Articles
# view all
# 🇪🇺 EU AI Act: Comments on the Third Code of Practice Draft 🇪🇺
# By
# frimelle
# and 1 other
# •
# about 10 hours ago
# •
# 5
# Making Gemma 3 think
# By
# burtenshaw
# •
# about 10 hours ago
# •
# 4
# unsloth_test_alpaca(一个unsloth炼丹的小例子)
# By
# aifeifei798
# •
# about 19 hours ago
# •
# 1
# Dynamic Intuition-Based Reasoning: A Novel Approach Toward Artificial General Intelligence
# By
# Veyllo
# •
# about 21 hours ago
# •
# 2
# Benchmarking Assisted Generation with Gemma 3 and Qwen 2.5: A Code-First Guide
# By
# ariG23498
# •
# 1 day ago
# •
# 1
# Messy Handwriting OCR Comparison Between Aya-Vision-8B and Qwen2VL-OCR-2B
# By
# prithivMLmods
# •
# 1 day ago
# •
# 11
# Open R1: Update #3
# By
# open-r1
# and 9 others
# •
# 2 days ago
# •
# 186
# Wan 2.1 Squish LoRA Video Tutorial
# By
# MonsterMMORPG
# •
# 3 days ago
# •
# 2
# 🌁#91: We are failing in AI literacy
# By
# Kseniase
# and 1 other
# •
# 3 days ago
# •
# 3
# Getting Started With Hugging Face in 10 Minutes
# By
# proflead
# •
# 3 days ago
# •
# 3
# How to choose your AI model
# By
# MichielBontenbal
# •
# 3 days ago
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# 3 days ago
# •
# 115
# 🦸🏻#13: Action! How AI Agents Execute Tasks with UI and API Tools
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# My Learning Journey: Understanding C
# By
# herooooooooo
# •
# 4 days ago
# •
# 4
# 🦸🏻#12: How Do Agents Learn from Their Own Mistakes? The Role of Reflection in AI
# By
# Kseniase
# •
# 4 days ago
# •
# 5
# What changed in the Transformer architecture
# By
# rishiraj
# •
# 5 days ago
# •
# 13
# 🌌 Synergistic Cognition & The Dalí AI Ganzfeld Experiment
# By
# TheMindExpansionNetwork
# •
# 6 days ago
# •
# 1
# 🌌 Synergistic Cognition: Master Plan White Paper - ALPHA UPDATED
# By
# TheMindExpansionNetwork
# •
# 6 days ago
# Beyond Python: AI Agents in JavaScript with KaibanJS
# By
# darielnoel
# •
# 7 days ago
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# 7 days ago
# •
# 16
# LeRobot goes to driving school: World’s largest open-source self-driving dataset
# By
# sandhawalia
# March 11, 2025
# •
# 40
# LLM Inference on Edge: A Fun and Easy Guide to run LLMs via React Native on your Phone!
# By
# medmekk
# March 7, 2025
# •
# 31
# Hugging Face and JFrog partner to make AI Security more transparent
# By
# mcpotato
# March 4, 2025
# •
# 20
# A Deepdive into Aya Vision: Advancing the Frontier of Multilingual Multimodality
# By
# saurabhdash
# March 4, 2025
# guest
# •
# 65
# Trace & Evaluate your Agent with Arize Phoenix
# By
# m-ric
# February 28, 2025
# guest
# •
# 31
# HuggingFace, IISc partner to supercharge model building on India's diverse languages
# By
# visruth-rf
# February 27, 2025
# •
# 14
# FastRTC: The Real-Time Communication Library for Python
# By
# freddyaboulton
# February 25, 2025
# •
# 141
# Remote VAEs for decoding with HF endpoints 🤗
# By
# hlky
# February 24, 2025
# •
# 36
# SigLIP 2: A better multilingual vision language encoder
# By
# ariG23498
# February 21, 2025
# •
# 133
# SmolVLM2: Bringing Video Understanding to Every Device
# By
# orrzohar
# February 20, 2025
# guest
# •
# 205
# PaliGemma 2 Mix - New Instruction Vision Language Models by Google
# By
# ariG23498
# February 19, 2025
# •
# 65
# Introducing Three New Serverless Inference Providers: Hyperbolic, Nebius AI Studio, and Novita 🔥
# By
# reach-vb
# February 18, 2025
# •
# 93
# Welcome Fireworks.ai on the Hub 🎆
# By
# julien-c
# February 14, 2025
# •
# 55
# Fixing Open LLM Leaderboard with Math-Verify
# By
# hynky
# February 14, 2025
# •
# 27
# Previous
# 1
# 2
# 3
# ...
# 39
# Next
# Community Articles
# view all
# 🇪🇺 EU AI Act: Comments on the Third Code of Practice Draft 🇪🇺
# By
# frimelle
# and 1 other
# •
# about 10 hours ago
# •
# 5
# Making Gemma 3 think
# By
# burtenshaw
# •
# about 10 hours ago
# •
# 4
# unsloth_test_alpaca(一个unsloth炼丹的小例子)
# By
# aifeifei798
# •
# about 19 hours ago
# •
# 1
# Dynamic Intuition-Based Reasoning: A Novel Approach Toward Artificial General Intelligence
# By
# Veyllo
# •
# about 21 hours ago
# •
# 2
# Benchmarking Assisted Generation with Gemma 3 and Qwen 2.5: A Code-First Guide
# By
# ariG23498
# •
# 1 day ago
# •
# 1
# Messy Handwriting OCR Comparison Between Aya-Vision-8B and Qwen2VL-OCR-2B
# By
# prithivMLmods
# •
# 1 day ago
# •
# 11
# Open R1: Update #3
# By
# open-r1
# and 9 others
# •
# 2 days ago
# •
# 186
# Wan 2.1 Squish LoRA Video Tutorial
# By
# MonsterMMORPG
# •
# 3 days ago
# •
# 2
# 🌁#91: We are failing in AI literacy
# By
# Kseniase
# and 1 other
# •
# 3 days ago
# •
# 3
# Getting Started With Hugging Face in 10 Minutes
# By
# proflead
# •
# 3 days ago
# •
# 3
# How to choose your AI model
# By
# MichielBontenbal
# •
# 3 days ago
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# 3 days ago
# •
# 115
# 🦸🏻#13: Action! How AI Agents Execute Tasks with UI and API Tools
# By
# Kseniase
# •
# 4 days ago
# •
# 4
# My Learning Journey: Understanding C
# By
# herooooooooo
# •
# 4 days ago
# •
# 4
# 🦸🏻#12: How Do Agents Learn from Their Own Mistakes? The Role of Reflection in AI
# By
# Kseniase
# •
# 4 days ago
# •
# 5
# What changed in the Transformer architecture
# By
# rishiraj
# •
# 5 days ago
# •
# 13
# 🌌 Synergistic Cognition & The Dalí AI Ganzfeld Experiment
# By
# TheMindExpansionNetwork
# •
# 6 days ago
# •
# 1
# 🌌 Synergistic Cognition: Master Plan White Paper - ALPHA UPDATED
# By
# TheMindExpansionNetwork
# •
# 6 days ago
# Beyond Python: AI Agents in JavaScript with KaibanJS
# By
# darielnoel
# •
# 7 days ago
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# 7 days ago
# •
# 16
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# forum page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# How to make my public space searchable
# Beginners
# 2
# 3
# March 13, 2025
# Comfyui pony prompts?
# Beginners
# 1
# 4
# March 13, 2025
# Blocking or hidding users
# Site Feedback
# 2
# 46
# March 13, 2025
# Getting Conversations to work in Unity
# Beginners
# 2
# 158
# March 13, 2025
# Model download statistics
# 🤗Hub
# 3
# 3
# March 13, 2025
# What is the best way to classify my content into tags?
# Beginners
# 1
# 6
# March 13, 2025
# Bug in models filtering by dataset?
# Site Feedback
# 3
# 3
# March 13, 2025
# Best Small LLM For Rag
# Models
# 4
# 106
# March 13, 2025
# Loading the Mdeberta-v3-base
# Models
# 5
# 4
# March 13, 2025
# Trying to convert DeepSeek-R1 into onnx
# 🤗Optimum
# 1
# 4
# March 13, 2025
# How to train a Model for Erotic Story Writing with Explicit Details?
# Beginners
# 3
# 15
# March 13, 2025
# Model inferencing is blocking the main fastapi thread
# Intermediate
# 0
# 5
# March 13, 2025
# Cannot access huggingface.co using specific IP Address.. ;;;
# Site Feedback
# 2
# 19
# March 13, 2025
# How to use export-onnx.py to change the pytorch_model.bin to onnx?
# Beginners
# 1
# 8
# March 12, 2025
# Problem with launching DeepSeek-R1-Distill-Qwen-32B-Uncensored-Q8_0-GGUF
# Models
# 1
# 14
# March 13, 2025
# Cannot import wan pipeline
# 🧨 Diffusers
# 1
# 18
# March 12, 2025
# Together Inference Credit finished
# Intermediate
# 1
# 10
# March 13, 2025
# Space interface does not load all of a sudden - No changes - just stopped working
# Spaces
# 1
# 6
# March 13, 2025
# Which Model For Resumes?
# Models
# 2
# 9
# March 13, 2025
# Seeking smart french-speaking model 10/30B to search large mythological texts
# Models
# 1
# 4
# March 13, 2025
# Network error when downloading weights for stable diffusion
# Beginners
# 2
# 426
# March 13, 2025
# Inquiry Regarding $10 Verification Hold Refund
# Beginners
# 2
# 17
# March 13, 2025
# AutoModel from_pretrained does not recursively download relative imports
# 🤗Hub
# 0
# 18
# March 11, 2025
# Corrupted deepspeed checkpoint
# DeepSpeed
# 1
# 5
# March 13, 2025
# Is there a data set on huggingface that has classified audio emotion?
# 🤗Datasets
# 1
# 5
# March 13, 2025
# OOM issue with large dataset streaming
# 🤗Datasets
# 4
# 34
# March 13, 2025
# Model does not exist, inference API don't work
# 🤗Transformers
# 5
# 66
# March 13, 2025
# Why is my DistilBERT model performing poorly on some classes despite hyperparameter tuning?
# Beginners
# 15
# 55
# March 9, 2025
# API inference limit changed?
# Intermediate
# 6
# 413
# March 12, 2025
# Which chunker to utilize for code based data
# Intermediate
# 1
# 11
# March 12, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 507 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# 910,455 followers
# 1h
# Report this post
# We're excited to be able to support
# arXiv
# in its mission to promote open science and research, by TRIPLING  donations you make today.
# arXiv
# has been helping the research community for the last >30 years, time to help back!
# https://lnkd.in/gyCBCjsu
# 23
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 5h
# Report this post
# Today we are supporting
# arXiv
# by 2:1 matching anyone's donation to ArXiv on March 13 (today's) Giving Day 💟💟
#
# ArXiv is central infrastructure for progress in AI that aim to be accessible not only to the biggest tech companies but to everyone on earth 🌍
#
# We at
# Hugging Face
# are proud to support ArXiv and will continue doing so.
# 285
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 9h
# Report this post
# Gemma 3's support for 140+ languages is a major step forward for inclusive and open AI. Kudos to the 200+ AI builders on
# Hugging Face
# who helped create the Global-MMLU benchmark.
#
# Thrilled to see Google using Global-MMLU to benchmark the progress across many languages.
#
# What can't be measured can't be improved.
#
# That's why we developed Global-MMLU a few months ago — to accelerate multilingual, open, and inclusive AI.
#
# Build together with the
# Hugging Face
# community and our friends at
# Cohere For AI
# ,
# Mila - Institut québécois d'intelligence artificielle
# ,
# EPFL
# ,
# Massachusetts Institute of Technology
# ,
# AI Singapore
# ,
# National University of Singapore
# ,
# KAIST
# ,
# Instituto Superior Técnico
# ,
# Carnegie Mellon University
# ,
# CONICET
# , and
# Universidad de Buenos Aires
# .
#
# Once again, you don't need to build models to be an AI builder and make a real impact.
#
# Let’s go!
# 152
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 910,455 followers
# 1d
# Report this post
# ArXiv is a fundamental pillar of the machine learning research community and we're very excited to be able to support it. Donate to ArXiv tomorrow during its annual Giving Day and, as a gift to the community, we will DOUBLE your donation ❤️
# arXiv
# 3,292 followers
# 2d
# This Thursday, support the future of
# #openscience
# with arXiv and
# Hugging Face
# !
#
# March 13th is Cornell Giving Day - a day to join together and give to the causes you care about. And this Cornell Giving Day, our friends at Hugging Face are making sure your donations make an even bigger impact. Hugging Face has pledged a $20,000 match to arXiv for
# #GivingDay
# , matching your donations 2:1. That means, when you give arXiv $10, Hugging Face will match it with $20 - basically tripling your donation!
#
# You give arXiv $1? Hugging Face gives $2!
# You give arXiv $1,000? Hugging Face gives $2,000!
#
# arXiv is a not-for-profit repository built for researchers, by researchers. Since 1991, arXiv has always been open and free to use, whether you're submitting new research, or reading one of the 2.5 million articles in our corpus. But we rely on you - your donations to arXiv really make a difference. Over 60% of arXiv's operating budget comes from the universities, libraries, research labs and researchers who use arXiv every day!
#
# Big or small, whatever you give, it all counts. If
# #open
# and
# #accessible
# science is important to you, give to arXiv this Giving Day. Thank you to Hugging Face and all the researchers who use and support arXiv.
#
# Save the date: at 12AM on Thursday, March 13th, this link will go live and you can give to arXiv in support of open science:
# https://lnkd.in/gyCBCjsu
# Give to arXiv | Cornell Giving Day
# givingday.cornell.edu
# 91
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,786 followers
# 1d
# Edited
# Report this post
# Tried
# Google DeepMind
# 's latest Gemma-3 release yet?
# Available on
# Hugging Face
# :
# https://lnkd.in/gr3hnVux
# 76
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,786 followers
# 1d
# Report this post
# wait what 🤯
#
# you can now see Gradio share links being created worldwide in REAL-TIME
#
# just launched:
# https://lnkd.in/gE9trefe
# - orange pulses = new shares (last 15s)
# - country color = usage intensity
# - completely privacy-preserving
#
# turns out gradio connects continents!
# …more
# 41
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,786 followers
# 2d
# Edited
# Report this post
# 🚀 New Research: Self-training inspires clear and concise thinking in LLMs!
#
# 30% reduction in tokens in LLM output, across five model families on GSM8K and MATH  while maintaining average accuracy 👀
#
# Useful links for Concise-Reasoning:
# > Code:
# https://lnkd.in/gPaeuXKE
# > Official app on
# Hugging Face
# :
# https://lnkd.in/gyG_hsri
# …more
# 40
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 2d
# Report this post
# 🤯 Cerebras' crazy inference speed is now available for everyone on
# Hugging Face
# . Generating thousands of samples in under 5 minutes is now a reality.
#
#
# Here I generate 100 rows in just 10 seconds with Llama70B using
# Cerebras Systems
# as Inference Provider.
#
# Do the test yourself here:
# https://lnkd.in/d6aS9NGY
# …more
# 159
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# 910,455 followers
# 2d
# Report this post
# Welcome,
# Cerebras Systems
# ! 🤗
# Alan Chhabra
# Executive Vice President, WW Partners @ Cerebras
# 2d
# Cerebras Systems
# AI Inference Cloud is now available through
# Hugging Face
# .
#
# To try it out, visit any of the Hugging Face model cards already supported by Cerebras Cloud. For instance, you can explore Llama 3.3 70B, select Cerebras as your provider, and experience blazing-fast inference directly via Hugging Face.
#
# Congrats to
# Julien Chaumond
# and team!
# https://lnkd.in/ehA9sF8y
# 109
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,786 followers
# 2d
# Edited
# Report this post
# DarkIR 🌑🌘🌕
#
# Now you can take photographs at night or in low-light conditions without concern. Say goodbye to noise, low light, and blurriness problems.
#
# Learn more about the new research or build locally:
# https://lnkd.in/gKEbuiC7
# DarkIR app is live on
# Hugging Face
# :
# https://lnkd.in/gAXmPef8
# 199
# 6 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# Perplexity
# Software Development
# San Francisco, California
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 46.2k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 141k
# 28.3k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 28k
# 5.8k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.8k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 17.7k
# 1.8k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.5k
# 1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.8k
# 509
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 300 repositories
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 27,999
# Apache-2.0
# 5,752
# 440
# (10 issues need help)
# 177
# Updated
# Mar 13, 2025
# smolagents
# Public
# 🤗 smolagents: a barebones library for agents. Agents write python code to call tools and orchestrate other agents.
# huggingface/smolagents’s past year of commit activity
# Python
# 14,664
# Apache-2.0
# 1,285
# 104
# 97
# Updated
# Mar 13, 2025
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 9,879
# Apache-2.0
# 1,162
# 218
# 23
# Updated
# Mar 13, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,551
# MIT
# 318
# 103
# (5 issues need help)
# 48
# Updated
# Mar 13, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 12,475
# Apache-2.0
# 1,683
# 293
# 68
# Updated
# Mar 13, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 141,156
# Apache-2.0
# 28,271
# 1,027
# (2 issues need help)
# 592
# Updated
# Mar 13, 2025
# open-r1
# Public
# Fully open reproduction of DeepSeek-R1
# huggingface/open-r1’s past year of commit activity
# Python
# 22,740
# Apache-2.0
# 2,042
# 206
# 39
# Updated
# Mar 13, 2025
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 175
# Apache-2.0
# 238
# 17
# (1 issue needs help)
# 37
# Updated
# Mar 13, 2025
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# huggingface/datasets’s past year of commit activity
# Python
# 19,779
# Apache-2.0
# 2,788
# 766
# (2 issues need help)
# 94
# Updated
# Mar 13, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,472
# Apache-2.0
# 1,049
# 103
# (2 issues need help)
# 22
# Updated
# Mar 13, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/QwQ-32B\nUpdated\n2 days ago\n•\n256k\n•\n2.11k\ngoogle/gemma-3-27b-it\nUpdated\n1 day ago\n•\n38.5k\n•\n459\ndeepseek-ai/DeepSeek-R1\nUpdated\n18 days ago\n•\n2.75M\n•\n11.3k\nSparkAudio/Spark-TTS-0.5B\nUpdated\n7 days ago\n•\n7.82k\n•\n380\nRekaAI/reka-flash-3\nUpdated\nabout 5 hours ago\n•\n1.3k\n•\n221\nBrowse 1M+ models\nSpaces\nRunning\n1.14k\n1.14k\nWan2.1\n💻\nWan: Open and Advanced Large-Scale Video Generative Models\nRunning\n371\n371\nQwQ 32B Demo\n🌖\nGenerate text responses to user prompts\nRunning\non\nZero\n417\n417\nDi♪♪Rhythm\n🎶\nBlazingly Fast and Embarrassingly Simple Song Generation\nRunning\n2.24k\n2.24k\nThe Ultra-Scale Playbook\n🌌\nThe ultimate guide to training LLM on large GPU Clusters\nRunning\non\nZero\n7.79k\n7.79k\nFLUX.1 [dev]\n🖥\nGenerate images from text prompts\nBrowse 400k+ applications\nDatasets\nFreedomIntelligence/medical-o1-reasoning-SFT\nUpdated\n20 days ago\n•\n27.9k\n•\n445\nfacebook/natural_reasoning\nUpdated\n21 days ago\n•\n10.7k\n•\n398\nCongliu/Chinese-DeepSeek-R1-Distill-data-110k\nUpdated\n21 days ago\n•\n7.74k\n•\n522\ngaia-benchmark/GAIA\nUpdated\n28 days ago\n•\n8.94k\n•\n258\nKodCode/KodCode-V1\nUpdated\n4 days ago\n•\n3.02k\n•\n63\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n395 models\n•\n2.79k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.07k models\n•\n5.04k followers\nAmazon\ncompany\n•\n11 models\n•\n2.85k followers\nGoogle\ncompany\n•\n968 models\n•\n9.2k followers\nIntel\ncompany\n•\n219 models\n•\n2.33k followers\nMicrosoft\ncompany\n•\n363 models\n•\n10.2k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n135 followers\nWriter\nEnterprise\ncompany\n•\n20 models\n•\n249 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n141,156\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n27,999\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,161\nSafe way to store/distribute neural network weights\nHub Python Library\n2,426\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,473\nFast tokenizers optimized for research & production\nTRL\n12,475\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,195\nState-of-the-art ML running directly in your browser\nsmolagents\n14,664\nSmol library to build great agents in Python\nPEFT\n17,746\nParameter-efficient finetuning for large language models\nDatasets\n19,779\ ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **The AI community building the future.**
# At Hugging Face, we're redefining the landscape of artificial intelligence by fostering collaboration among machine learning experts, researchers, and developers.
#
# ---
#
# ## What We Do
# Hugging Face serves as a **collaboration platform** where the machine learning community can work together on:
# - **Models:** Access to over 1M+ cutting-edge models.
# - **Datasets:** A repository of 250k+ datasets for various ML tasks.
# - **Applications:** Various Spaces for users to build and demo AI apps.
#
# ### Enterprise Solutions
# We provide **paid compute and enterprise solutions** for organizations looking to leverage our platform securely and effectively, starting at **$20/user/month**.
#
# ---
#
# ## Company Culture
# At Hugging Face, our culture is built on collaboration, **openness**, and **innovation**:
# - We prioritize a community-driven approach to development.
# - Our open-source resources empower users to participate actively and help each other grow.
# - A supportive workspace encourages every team member to contribute, experiment, and learn.
#
# ---
#
# ## Our Customers
# We proudly serve over **50,000 organizations**, including industry leaders:
# - **Meta**
# - **Google**
# - **Microsoft**
# - **Amazon**
# These partnerships highlight our commitment to providing enterprise-grade solutions and maintaining a robust selection of models for commercial use.
#
# ---
#
# ## Careers at Hugging Face
# Join our growing family at Hugging Face! We are always looking for passionate individuals excited about **AI and machine learning.** We offer roles in various capacities including:
# - **Engineering**
# - **Design**
# - **Community Engagement**
# - **Marketing**
#
# ### Why Work with Us?
# - Engage with a diverse team of talented individuals.
# - Work on pioneering projects at the forefront of AI technology.
# - Contribute to an open-source environment that shapes the future of machine learning.
#
# ---
#
# ## Connect With Us
# Join our thriving community today!
# - [Explore AI Apps](https://huggingface.co)
# - [Browse Models](https://huggingface.co/models)
# - [Sign Up](https://huggingface.co/join)
#
# Stay updated with our latest developments through our **[Blog](https://huggingface.co/blog)** and connect with us on **[GitHub](https://github.com/huggingface)**, **[Twitter](https://twitter.com/huggingface)**, and **[Discord](https://discord.gg/huggingface)**!
#
# ---
#
# **Together, let's build tomorrow's AI.**
# **Hugging Face - The Home of Machine Learning**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}]}
# # Hugging Face Brochure
#
# ### Welcome to Hugging Face
# **The AI community building the future.** Hugging Face is the leading platform where the machine learning community collaborates on models, datasets, and applications. With a vast repository of over **1 million models** and **250,000 datasets**, we are committed to empowering innovators and researchers at every stage of their AI journey.
#
# ---
#
# ### Our Mission
# At Hugging Face, we envision a world where machine learning is more accessible and collaborative. Our open-source tools and shared resources foster creativity and accelerate research, enabling developers to create cutting-edge AI technologies together.
#
# ### What We Offer
# - **Models:** Explore a diverse range of pre-trained models and contribute to the ever-growing repository.
# - **Datasets:** Access and share datasets for any ML tasks, facilitating better training and evaluation.
# - **Spaces:** Share and deploy machine learning demos and applications with ease.
# - **Enterprise Solutions:** We provide tailored compute and enterprise solutions designed to cater to the unique needs of organizations with advanced security and support.
#
# ---
#
# ### Our Community
# With **more than 50,000 organizations** leveraging our platform, Hugging Face is proud to collaborate with leading tech giants, including:
# - Google
# - Microsoft
# - Amazon
# - Intel
# - Many more…
#
# Join a vibrant community that comprises enthusiasts, researchers, and enterprises, all working towards the advancement of AI.
#
# ---
#
# ### Company Culture
# At Hugging Face, we are dedicated to cultivating an inclusive and empowering environment. Our remote-first culture embraces diversity, encourages continuous learning, and promotes collaboration. As part of our team, you will have the opportunity to work on innovative projects and contribute to open-source initiatives, all while being surrounded by passionate individuals who care about building the future of AI.
#
# ### Career Opportunities
# We’re always on the lookout for talent to join our mission! Explore exciting careers in:
# - Machine Learning Engineering
# - Software Development
# - Data Science
# - Community Management
#
# **Join us:** Check our [Careers page](https://huggingface.co/jobs) to view current open positions and become a part of our journey towards transforming the AI landscape.
#
# ---
#
# ### Connect with Us
# Stay updated with our latest news and contributions by following us:
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/huggingface)
# - [Discord Community](https://discord.gg/huggingface)
#
# **Ready to shape the future of AI?** Sign up today and start collaborating on models and datasets that will push the boundaries of what's possible in machine learning!
#
# ---
#
# For more information, visit our [website](https://huggingface.co) and be part of this exciting journey.

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("Sislogica", "https://www.sislogica.com.br/")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://www.sislogica.com.br/#sobre'}, {'type': 'services page', 'url': 'https://www.sislogica.com.br/#servicos'}, {'type': 'clients page', 'url': 'https://www.sislogica.com.br/#clientes'}, {'type': 'contact page', 'url': 'https://www.sislogica.com.br/#contact'}]}
# # Sislogica Brochure
#
# ---
#
# ## Welcome to Sislogica
#
# At **Sislogica**, we are dedicated to developing tailor-made corporate solutions specifically designed to enhance logistics and delivery operations. Our team combines cutting-edge technology with a highly skilled workforce to meet the unique needs of our clients.
#
# ---
#
# ### About Us
#
# Founded to address the growing demands in the logistics and delivery sector, Sislogica leverages over 20 years of technical expertise in system development. We're committed to providing creative and efficient logistics solutions, including:
#
# - Reverse logistics
# - First Mile and Last Mile deliveries
# - Cargo management
#
# Our operations are built on robust data security, ensuring that our clients’ information is always protected.
#
# ---
#
# ### Our Mission
#
# We aim to exceed client expectations through intelligent solutions, harnessing technology and a dedicated workforce. Our core values—**Simplicity, Objectivity, Respect, Humility, and Determination**—guide our everyday actions and decisions.
#
# ---
#
# ### Services
#
# **TMSLOG** - Our Transportation Management System is a modular platform that offers various functionalities to meet specific client needs, including:
#
# - Route planning
# - First, Middle, and Last Mile logistics
# - WhatsApp integration
# - Damage control and compensation module
# - Customer Service Module
# - TMS Drivers App
# - Driver monetization
# - Issuance of NF-e, CT-e, and MDF-e
# - Control Dashboards
# - Tracking management
#
# **SISEDI** - Our Middleware tool integrates information using various technologies such as API, Web Service, FTP, and SFTP, ensuring seamless connectivity between systems.
#
# ---
#
# ### Infrastructure
#
# Sislogica operates with a robust infrastructure supported by high-performance AWS cloud servers. This guarantees high availability, security, and privacy for your data.
#
# ---
#
# ### Our Customers
#
# We proudly serve leading brands and companies, providing them with innovative logistics solutions that streamline their operations.
#
# ---
#
# ### Join Our Team
#
# As a growing company, we are constantly looking for talented and motivated individuals to join our team. Sislogica offers a dynamic work environment focused on professional development and collaboration. If you are ready to be part of a team that values integrity and innovation, explore our career opportunities.
#
# ---
#
# ### Get In Touch
#
# **Location:**
# Av.Sagitário, 138, Torre: London - 1608, Barueri - SP, 06473-073
#
# **Email:** [suporte@sislogica.com.br](mailto:suporte@sislogica.com.br)
#
# **Phone:** +55 11 94581-3860
#
# ---
#
# **Copyright © Sislogica Sistema de Informação Ltda. All Rights Reserved.**

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

MODEL = 'gpt-4o-mini'
openai = OpenAI()

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}
class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers = headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "Titulo nao encontrado"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator = "\n", strip = True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

        def get_contents(self):
            return f"Titulo da Pagina web: \n {self.title}\nConteudo da pagina web: \n{self.text}\n\n"

# %%
sl = Website("https://edwarddonner.com")
sl.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %%
link_system_prompt = """You are provided with a list of links found on a webpage. 
You are able to decide which of the links would be most relevant to include in a brochure about the company, 
such as links to an About page, or a Company page, or Careers/Jobs pages.

You should respond in JSON as in this example:"""

link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage.
# You are able to decide which of the links would be most relevant to include in a brochure about the company,
# such as links to an About page, or a Company page, or Careers/Jobs pages.
#
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a marketing/pitch/brouche presentation. Please do not include Terms of Service, emails, Privacy and this dispensable for picth/marketing information.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(sl))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a marketing/pitch/brouche presentation. Please do not include Terms of Service, emails, Privacy and this dispensable for picth/marketing information.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = MODEL,
        messages = [
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
        ],
        response_format = {"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
def get_all_details(url):
    result = "Landing page: \n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found link:",links)
    for link in links["links"]:
        result += f"\n\n{link['type']}:\n"
        result += Website (link['url']).get_contents()
    return result
